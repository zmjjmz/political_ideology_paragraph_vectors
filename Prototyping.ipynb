# %%
# We need to check if every word in the IBC corpus is present in our common crawl vectors

# So there is 5.3GB of common crawl information. We can't hope to store all of this in memory, so instead
# we're going to get an index of word -> line, then cache it once it's accessed
import linecache
import numpy as np
import codecs
# from io import open

class GloVeLoader:
    index = {}
    def __init__(self, filen):
        """Generate the word -> file position index"""
        self.filen = filen
        with open(self.filen, 'r', encoding='utf-8') as gf:
            self.total_lines, self.dim = map(int,gf.readline().split())
            self.null_vec = np.zeros(self.dim)
            while True:
                start_pos = gf.tell()
                line = gf.readline()
                if line == '':
                    break
                word = line.split(' ')[0]
                self.index[word] = start_pos
                self.total_lines += 1
        
    def get(self, word):
        """Gets the floats stored for that word using seek"""
        #line = linecache.getline(self.filen,self.index[word])
        # linecache does not work for this. It reads the whole thing in (virtual) memory, crashing
        pos = self.index[word]
        line = ''
        with open(self.filen, 'r', encoding='utf-8') as tmp:
            tmp.seek(pos)
            line = tmp.readline()
        if line == '':
            print("Looked for %s (position %d), got an error" % (word, self.index[word]))
            # note be careful that it's returning a ref, don't mutate
            return self.null_vec
        vals = line.split(' ')
        if vals[0] != word:
            print("Looked for %s (position %d), got %s. Something went wrong" % (word, self.index[word], vals[0]))
            return self.null_vec
        return np.array(list(map(float,vals[1:])))
    
    def clearcache(self):
        """Clear cache if the GloVe words need to be reloaded"""
        linecache.clearcache()

# %%
import time
tic = time.time()
commcrawl_vecs = GloVeLoader("word_reps/glove/glove.840B.300d--modified.txt")
toc = time.time() - tic
print("Took %f seconds" % toc)
# Out:
# Took 59.573014 seconds

# %%
commcrawl_vecs.index['Glass-Steagal']
# Out:
# 2148135976

# %%
import pickle
IBC = pickle.load(open("full_ibc/ibcData.pkl",'rb'))

# %%
dictIBC = {"liberal":[sent.get_words().split(' ') for sent in IBC[0]],
           "conservative":[sent.get_words().split(' ') for sent in IBC[1]],
           "neutral":[sent.get_words().split(' ') for sent in IBC[2]]}

# %%
total_problematic = 0
for label in ["liberal","conservative","neutral"]:
    total_sents = len(dictIBC[label])
    sents_w_missing = 0    
    for sent in dictIBC[label]:
        old_p = total_problematic
        for word in sent:
            if word not in commcrawl_vecs.index:
                total_problematic += 1
        if old_p != total_problematic:
            sents_w_missing += 1
    print("%s has %d sentences with unknown words out of %d sentences total" % (label, sents_w_missing, total_sents))
print(total_problematic)
skipped = set()

# %%
from IPython.display import clear_output
def insert_multi(lis, ind, ins):
    """Utility function to input a string of multiple tokens into a position"""
    lis.pop(ind)
    for ins_ind, ins_i in enumerate(ins):
        lis.insert(ind+ins_ind,ins_i)
    
def get_context(lis, ind):
    """Utility function to get string of surrounding words, handles bounds"""
    if ind > 0 and ind < len(lis)-1:
        return ' '.join([lis[ind-1],lis[ind],lis[ind+1]])
    elif ind > 0:
        return ' '.join([lis[ind-1],lis[ind]])
    else:
        return ' '.join([lis[ind],lis[ind+1]])
        
def check_valid(lis, index):
    in_ind = [i in index for i in lis]
    return (all(in_ind), [lis[ind] for ind in range(len(lis)) if not in_ind[ind]])


for label in ["liberal","conservative","neutral"]:
    for sent in dictIBC[label]:
        for ind, word in enumerate(sent):
            if word not in commcrawl_vecs.index and (word not in skipped):
                print("Word %s from IBC not found in Common Crawl" % (word))
                print("Context %s" % get_context(sent, ind))
                print("""1: leave as is
2: typo, let me fix
3: split on -
4: remove -
5: join with left token
6: join with right token
7: join all three
8: remove \\""")
                command = input().rstrip()
                if command == "1":
                    skipped.add(word)
                if command == "2":
                    print("Ok, type it:")
                    new_word = input().rstrip()
                    use = True
                    while (True):
                        in_ind = [i in commcrawl_vecs.index for i in new_word.split(' ')]
                        if all(in_ind):
                            break
                        else:    
                            print("%r not in the index. Try again? Type $$skip$$ to skip it" % 
                                  [new_word.split(' ')[idx] for idx in range(len(in_ind)) if not in_ind[idx]])
                        new_word = input().rstrip()
                        if new_word == "$$skip$$":
                            use=False
                            skipped.add(word)
                            break
                    if use:
                        insert_multi(sent, ind, new_word.split(' '))
                if command == "3":
                    new_words = word.split('-')
                    insert_multi(sent, ind, new_words)
                if command == "4":
                    new_word = word.replace('-','')
                    sent[ind] = new_word
                if command == "5":
                    if ind == 0:
                        print("no. continuing")
                        continue
                    new_word = sent[ind-1] + sent[ind]
                    sent[ind] = new_word
                    sent.pop(ind-1)
                if command == "6":
                    if ind >= len(sent):
                        print("nope. continuing")
                        continue
                    new_word = sent[ind] + sent[ind+1]
                    sent[ind] = new_word
                    sent.pop(ind+1)
                if command == "7":
                    if ind >= len(sent) or ind == 0:
                        print("fuck you. continuing")
                        continue
                    new_word = sent[ind-1] + sent[ind] + send[ind+1]
                    sent[ind] = new_word
                    sent.pop(ind+1)
                    sent.pop(ind-1)
                if command == "8":
                    new_word = word.replace('\\','')
                    sent[ind] = new_word
                print("Skipping")
                clear_output()

# %%
pickle.dump(dictIBC,open("full_ibc/cleaned_IBCdict.pkl",'wb'))

# %%
dictIBC_cleaned = pickle.load(open("full_ibc/cleaned_IBCdict.pkl",'rb'))

# %%
dictIBC_cr = {key:[] for key in dictIBC_cleaned} # new dictionary to hold data that 
for label in dictIBC_cleaned:
    for sent in dictIBC_cleaned[label]:
        if all([word in commcrawl_vecs.index for word in sent]):
            dictIBC_cr[label].append(sent)

# %%
print("Remaining sentences")
for label in dictIBC_cr:
    print("%s: %d / %d" % (label, len(dictIBC_cr[label]), len(dictIBC_cleaned[label])))
# Out:
# Remaining sentences
# conservative: 1674 / 1701
# neutral: 587 / 600
# liberal: 1984 / 2025

# %%
from sklearn.feature_extraction.text import TfidfTransformer, TfidfVectorizer
flatIBC = []
for label in dictIBC_cr:
    for sent in dictIBC_cr[label]:
        flatIBC.append(' '.join(sent))
#print(flatIBC)
vectorizer = TfidfVectorizer(lowercase=False)
X = vectorizer.fit_transform(flatIBC)
idf = vectorizer._tfidf.idf_
idfWeights = dict(zip(vectorizer.get_feature_names(), idf))
get_tf = lambda doc: {word:doc.count(word) / float(len(doc)) for word in doc}
# normalize IDF to maximum
max_idf = max(idfWeights.values())
for word in idfWeights:
    idfWeights[word] /= max_idf

def tfidf_vector(sent, loader, idf):
    idf_safe = lambda x: idf[x] if x in idf else 1
    tf = get_tf(sent)
    return np.sum([loader.get(word) * (tf[word] * idf_safe(word)) for word in sent],axis=0)

# %%
from scipy.spatial.distance import cosine

tfvec = tfidf_vector("I ran into the bushes .".split(),commcrawl_vecs,idfWeights)
tfvec2 = tfidf_vector("I walked into the bushes .".split(),commcrawl_vecs,idfWeights)
tfvec3 = tfidf_vector("Fuck her right in the pussy .".split(),commcrawl_vecs,idfWeights)
print(cosine(tfvec,tfvec2))
print(cosine(tfvec,tfvec3))
# Out:
# 0.0373067117898
# 0.397752479758

# %%
def avg_vector(sent, loader):
    """ Get the average vector of a sentence by just taking the sum of the vectors and dividing by sqrt(len(sent))"""
    return np.sum([loader.get(word) for word in sent],axis=0) / np.sqrt(len(sent))

vec1 = avg_vector("I ran into the bushes .".split(),commcrawl_vecs)
vec2 = avg_vector("I walked into the bushes .".split(),commcrawl_vecs)
vec3 = avg_vector("Fuck her right in the pussy .".split(),commcrawl_vecs)
print(cosine(vec1,vec2))
print(cosine(vec1,vec3))
# Out:
# 0.0292427489528
# 0.258901846427

# %%
# Train on average*sqrt(n) vectors
from sklearn import svm, cross_validation
avgX = []
avgy = []
for label in dictIBC_cr:
    for sent in dictIBC_cr[label]:
        avgX.append(avg_vector(sent,commcrawl_vecs))
        avgy.append(label)
avgX_train, avgX_test, avgy_train, avgy_test = cross_validation.train_test_split(avgX,avgy,test_size=0.25)
avg_linear_svc = svm.SVC(kernel="linear").fit(avgX_train, avgy_train)
avg_rbf_svc = svm.SVC(kernel="rbf").fit(avgX_train, avgy_train)
print("linearSVM avgVec: ",avg_linear_svc.score(avgX_test,avgy_test))
print("rbfSVM avgVec: ",avg_rbf_svc.score(avgX_test,avgy_test))
# Out:
# linearSVM avgVec:  0.559322033898
# rbfSVM avgVec:
#  0.581920903955

# %%
tfX = []
tfy = []
for label in dictIBC_cr:
    for sent in dictIBC_cr[label]:
        tfX.append(tfidf_vector(sent,commcrawl_vecs,idfWeights))
        tfy.append(label)
tfX_train, tfX_test, tfy_train, tfy_test = cross_validation.train_test_split(tfX,tfy,test_size=0.25)
tf_linear_svc = svm.SVC(kernel="linear").fit(tfX_train, tfy_train)
tf_rbf_svc = svm.SVC(kernel="rbf").fit(tfX_train, tfy_train)
print("linearSVM tfidf: ",tf_linear_svc.score(tfX_test,tfy_test))
print("rbfSVM tfidf: ",tf_rbf_svc.score(tfX_test,tfy_test))
# Out:
# linearSVM tfidf:  0.530131826742
# rbfSVM tfidf:
#  0.449152542373

# %%
# %matplotlib inline
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
def cosine_(x,y,squared=True):
    return cosine(x,y)
avgTSNE_model = TSNE(verbose=3,metric=cosine_,learning_rate=100).fit_transform(avgX)
tfTSNE_model = TSNE(verbose=3,metric=cosine_,learning_rate=100).fit_transform(tfX)
# Out:
# [t-SNE] Computing pairwise distances...
# [t-SNE] Computed conditional probabilities for sample 1000 / 4245
# [t-SNE] Computed conditional probabilities for sample 2000 / 4245
# [t-SNE] Computed conditional probabilities for sample 3000 / 4245
# [t-SNE] Computed conditional probabilities for sample 4000 / 4245
# [t-SNE] Computed conditional probabilities for sample 4245 / 4245
# [t-SNE] Mean sigma: 0.058437
# [t-SNE] Iteration 10: error = 23.5077756, gradient norm = 0.0211545
# [t-SNE] Iteration 20: error = 23.6049229, gradient norm = 0.0554825
# [t-SNE] Iteration 30: error = 23.7277013, gradient norm = 0.0660271
# [t-SNE] Iteration 33: did not make any progress during the last 30 episodes. Finished.
# [t-SNE] Iteration 40: error = 23.6204595, gradient norm = 0.0374233
# [t-SNE] Iteration 50: error = 23.5850290, gradient norm = 0.0424378
# [t-SNE] Iteration 60: error = 23.6133451, gradient norm = 0.0564694
# [t-SNE] Iteration 70: error = 23.6476502, gradient norm = 0.0651539
# [t-SNE] Iteration 75: did not make any progress during the last 30 episodes. Finished.
# [t-SNE] Error after 75 iterations with early exaggeration: 23.688494
# [t-SNE] Iteration 80: error = 4.4716991, gradient norm = 0.0143078
# [t-SNE] Iteration 90: error = 4.2198677, gradient norm = 0.0099471
# [t-SNE] Iteration 100: error = 4.0514656, gradient norm = 0.0078788
# [t-SNE] Iteration 110: error = 3.9542911, gradient norm = 0.0077536
# [t-SNE] Iteration 120: error = 3.8952046, gradient norm = 0.0075135
# [t-SNE] Iteration 130: error = 3.8612594, gradient norm = 0.0072882
# [t-SNE] Iteration 140: error = 3.8419577, gradient norm = 0.0071360
# [t-SNE] Iteration 150: error = 3.8308481, gradient norm = 0.0070420
# [t-SNE] Iteration 160: error = 3.8243667, gradient norm = 0.0069852
# [t-SNE] Iteration 170: error = 3.8205481, gradient norm = 0.0069512
# [t-SNE] Iteration 180: error = 3.8182839, gradient norm = 0.0069309
# [t-SNE] Iteration 190: error = 3.8169363, gradient norm = 0.0069187
# [t-SNE] Iteration 200: error = 3.8161323, gradient norm = 0.0069115
# [t-SNE] Iteration 210: error = 3.8156519, gradient norm = 0.0069071
# [t-SNE] Iteration 220: error = 3.8153646, gradient norm = 0.0069045
# [t-SNE] Iteration 230: error = 3.8151928, gradient norm = 0.0069029
# [t-SNE] Iteration 240: error = 3.8150899, gradient norm = 0.0069020
# [t-SNE] Iteration 250: error = 3.8150283, gradient norm = 0.0069015
# [t-SNE] Iteration 260: error = 3.8149915, gradient norm = 0.0069011
# [t-SNE] Iteration 270: error = 3.8149694, gradient norm = 0.0069009
# [t-SNE] Iteration 280: error = 3.8149562, gradient norm = 0.0069008
# [t-SNE] Iteration 290: error = 3.8149483, gradient norm = 0.0069007
# [t-SNE] Iteration 300: error = 3.8149436, gradient norm = 0.0069007
# [t-SNE] Iteration 310: error = 3.8149407, gradient norm = 0.0069007
# [t-SNE] Iteration 320: error = 3.8149390, gradient norm = 0.0069006
# [t-SNE] Iteration 326: error difference 0.000000. Finished.
# [t-SNE] Error after 326 iterations: 3.814938
# [t-SNE] Computing pairwise distances...
# [t-SNE] Computed conditional probabilities for sample 1000 / 4245
# [t-SNE] Computed conditional probabilities for sample 2000 / 4245
# [t-SNE] Computed conditional probabilities for sample 3000 / 4245
# [t-SNE] Computed conditional probabilities for sample 4000 / 4245
# [t-SNE] Computed conditional probabilities for sample 4245 / 4245
# [t-SNE] Mean sigma: 0.068719
# [t-SNE] Iteration 10: error = 23.5485208, gradient norm = 0.0196788
# [t-SNE] Iteration 20: error = 23.5944721, gradient norm = 0.0422501
# [t-SNE] Iteration 30: error = 23.6824567, gradient norm = 0.0513237
# [t-SNE] Iteration 33: did not make any progress during the last 30 episodes. Finished.
# [t-SNE] Iteration 40: error = 23.5872220, gradient norm = 0.0364216
# [t-SNE] Iteration 50: error = 23.5680772, gradient norm = 0.0347266
# [t-SNE] Iteration 60: error = 23.5681167, gradient norm = 0.0405933
# [t-SNE] Iteration 66: did not make any progress during the last 30 episodes. Finished.
# [t-SNE] Error after 66 iterations with early exaggeration: 23.591558
# [t-SNE] Iteration 70: error = 4.4775598, gradient norm = 0.0098138
# [t-SNE] Iteration 80: error = 4.2175235, gradient norm = 0.0099841
# [t-SNE] Iteration 90: error = 4.0131611, gradient norm = 0.0078882
# [t-SNE] Iteration 100: error = 3.9133232, gradient norm = 0.0074303
# [t-SNE] Iteration 110: error = 3.8559675, gradient norm = 0.0073932
# [t-SNE] Iteration 120: error = 3.8209268, gradient norm = 0.0073594
# [t-SNE] Iteration 130: error = 3.7997390, gradient norm = 0.0073152
# [t-SNE] Iteration 140: error = 3.7870635, gradient norm = 0.0072801
# [t-SNE] Iteration 150: error = 3.7795008, gradient norm = 0.0072565
# [t-SNE] Iteration 160: error = 3.7749863, gradient norm = 0.0072417
# [t-SNE] Iteration 170: error = 3.7722888, gradient norm = 0.0072326
# [t-SNE] Iteration 180: error = 3.7706758, gradient norm = 0.0072272
# [t-SNE] Iteration 190: error = 3.7697107, gradient norm = 0.0072239
# [t-SNE] Iteration 200: error = 3.7691332, gradient norm = 0.0072219
# [t-SNE] Iteration 210: error = 3.7687875, gradient norm = 0.0072207
# [t-SNE] Iteration 220: error = 3.7685805, gradient norm = 0.0072200
# [t-SNE] Iteration 230: error = 3.7684566, gradient norm = 0.0072196
# [t-SNE] Iteration 240: error = 3.7683824, gradient norm = 0.0072194
# [t-SNE] Iteration 250: error = 3.7683380, gradient norm = 0.0072192
# [t-SNE] Iteration 260: error = 3.7683114, gradient norm = 0.0072191
# [t-SNE] Iteration 270: error = 3.7682955, gradient norm = 0.0072191
# [t-SNE] Iteration 280: error = 3.7682860, gradient norm = 0.0072190
# [t-SNE] Iteration 290: error = 3.7682802, gradient norm = 0.0072190
# [t-SNE] Iteration 300: error = 3.7682768, gradient norm = 0.0072190
# [t-SNE] Iteration 310: error = 3.7682748, gradient norm = 0.0072190
# [t-SNE] Iteration 320: error difference 0.000000. Finished.
# [t-SNE] Error after 320 iterations: 3.768274

# %%
color_dict = {'liberal':'b','conservative':'r','neutral':'k'}
colors = [color_dict[i] for i in avgy]
plt.scatter(*zip(*avgTSNE_model),c=colors)
plt.show()

# %%
colors = [color_dict[i] for i in tfy]
plt.scatter(*zip(*tfTSNE_model),c=colors)
plt.show()

# %%
from sklearn.cluster import KMeans
kmc = KMeans(n_clusters=3)
avg_cind = kmc.fit_predict(avgX)
tf_cind = kmc.fit_predict(tfX)
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int32)

# %%
cluster_colors = {0:'b',1:'r',2:'k'}
colors_avg = [cluster_colors[i] for i in avg_cind]
colors_tf = [cluster_colors[i] for i in tf_cind]
plt.scatter(*zip(*avgTSNE_model),c=colors_avg)
plt.show()

# %%
plt.scatter(*zip(*tfTSNE_model),c=colors_tf)
plt.show()
